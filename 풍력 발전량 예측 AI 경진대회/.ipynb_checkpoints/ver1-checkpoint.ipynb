# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19275 entries, 0 to 19274
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19275 non-null  object
#  1   temperature     19275 non-null  float64
#  2   pressure        19275 non-null  float64
#  3   humidity        19275 non-null  float64
#  4   wind_speed      19275 non-null  float64
#  5   wind_direction  19275 non-null  float64
#  6   precipitation   19275 non-null  float64
#  7   snowing         19275 non-null  bool
#  8   cloudiness      19275 non-null  float64
#  9   target          19275 non-null  float64
# dtypes: bool(1), float64(8), object(1)
# memory usage: 1.3+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19275 entries, 0 to 19274
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19275 non-null  object
#  1   temperature     19275 non-null  float64
#  2   pressure        19275 non-null  float64
#  3   humidity        19275 non-null  float64
#  4   wind_speed      19275 non-null  float64
#  5   wind_direction  19275 non-null  float64
#  6   precipitation   19275 non-null  float64
#  7   snowing         19275 non-null  bool
#  8   cloudiness      19275 non-null  float64
# dtypes: bool(1), float64(7), object(1)
# memory usage: 1.2+ MB

# %%
train.head(5)
# Out:
#             id  temperature  pressure  humidity  wind_speed  wind_direction  \
# 0  TRAIN_00000      27.8816    1013.6      46.8         2.4           232.4
# 1  TRAIN_00001       5.7540    1026.6      76.6         3.6           172.0
# 2  TRAIN_00002      20.8220    1016.2      64.8         2.2           206.0
# 3  TRAIN_00003      20.0758    1017.4      72.6         0.8           215.4
# 4  TRAIN_00004       7.5260    1023.2      82.8         1.2           158.0
#
#    precipitation  snowing  cloudiness  target
# 0           0.00    False         0.0   1.180
# 1           0.00    False         8.8   8.581
# 2           0.06    False        23.0   3.978
# 3           0.00    False         0.0   8.301
# 4           0.00    False        15.0   1.692

# %%
train.describe()
# Out:
#         temperature       pressure      humidity    wind_speed  \
# count  19275.000000   19275.000000  19275.000000  19275.000000
# mean      17.288476    1059.825712     68.948763      2.476970
# std        7.192604    2544.132430     14.856929      1.359942
# min       -0.208137     812.600000     22.600000      0.000000
# 25%       11.712000    1012.600000     57.800000      1.400000
# 50%       16.530000    1016.800000     70.800000      2.200000
# 75%       22.559000    1021.000000     80.800000      3.200000
# max       37.058000  201373.000000    100.000000     29.800000
#
#        wind_direction  precipitation    cloudiness        target
# count    19275.000000   19275.000000  19275.000000  19275.000000
# mean       166.578179       0.076572     25.749748      5.477028
# std         57.313099       0.193110     17.628612      3.217581
# min          0.000000       0.000000      0.000000      0.000000
# 25%        127.000000       0.000000     12.000000      2.956000
# 50%        166.600000       0.000000     23.000000      4.837000
# 75%        208.000000       0.060000     37.000000      7.436500
# max        338.000000       3.180000     93.600000     17.344000

# %%
test.describe()
# Out:
#         temperature       pressure      humidity    wind_speed  \
# count  19275.000000   19275.000000  19275.000000  19275.000000
# mean      17.234841    1070.601639     68.924182      2.495699
# std        7.191292    2591.110215     14.794539      1.365812
# min       -0.091600     812.400000     24.400000      0.200000
# 25%       11.704250    1012.600000     57.800000      1.400000
# 50%       16.498000    1016.800000     70.600000      2.200000
# 75%       22.550000    1021.000000     80.800000      3.200000
# max       37.116000  202469.000000    100.000000     17.400000
#
#        wind_direction  precipitation    cloudiness
# count    19275.000000   19275.000000  19275.000000
# mean       166.699642       0.077166     25.564887
# std         57.041635       0.198388     17.583694
# min          0.000000       0.000000      0.000000
# 25%        127.000000       0.000000     12.000000
# 50%        166.000000       0.000000     23.000000
# 75%        206.000000       0.060000     36.600000
# max        337.000000       3.180000     92.000000

# %%
train.loc[train['pressure']>= 1100]
# Out:
#                 id  temperature  pressure  humidity  wind_speed  \
# 495    TRAIN_00495     9.178200  201149.4      71.4         4.6
# 970    TRAIN_00970     9.638300   21229.4      63.8         1.0
# 999    TRAIN_00999    11.862600   21217.8      60.4         1.4
# 1361   TRAIN_01361     7.499469   20825.0      57.0         3.4
# 1788   TRAIN_01788    11.926000   21151.4      56.2         3.6
# 4754   TRAIN_04754     7.979063   21008.2      69.0         2.8
# 5186   TRAIN_05186    11.363000   20808.6      67.8         3.2
# 5823   TRAIN_05823    11.105400   10882.2      62.6         5.4
# 6402   TRAIN_06402    12.583600   21198.8      61.0         2.0
# 6559   TRAIN_06559     9.613200   20799.0      53.6         4.0
# 8559   TRAIN_08559    10.380194    8906.2      60.0         1.2
# 9951   TRAIN_09951     8.957800   20841.2      71.2         3.6
# 11296  TRAIN_11296    11.929769    2827.2      54.8         1.6
# 11612  TRAIN_11612     9.984200    2803.0      55.0         4.0
# 12659  TRAIN_12659     9.178863  201373.0      56.0         2.4
# 13294  TRAIN_13294     9.384100  201093.6      71.6         3.8
# 15057  TRAIN_15057    14.378100   21113.4      52.2         2.0
# 18742  TRAIN_18742     8.492100   20858.4      70.2         2.0
#
#        wind_direction  precipitation  snowing  cloudiness  target
# 495             278.0           0.24    False        68.8   8.606
# 970             139.8           0.06    False        27.2   3.874
# 999             133.0           2.46    False        33.6   3.999
# 1361            265.0           0.18    False        18.4   9.665
# 1788            205.0           0.06    False        47.2   5.937
# 4754            161.8           2.58    False        56.0   5.937
# 5186            208.8           0.24    False        49.6  12.797
# 5823            288.6           0.66    False        24.0  12.254
# 6402            172.2           0.06    False        34.4   4.601
# 6559            304.2           3.00    False        18.4  11.342
# 8559            192.0           0.06    False        45.2   6.125
# 9951            279.2           0.24    False        68.8   8.085
# 11296           188.6           0.06    False        43.6   6.138
# 11612           275.4           0.18    False        18.4  11.320
# 12659           253.8           0.18    False        18.4  10.241
# 13294           293.6           0.24    False        68.8   9.683
# 15057           188.2           0.06    False        32.0   6.141
# 18742           275.2           0.18    False        59.2   7.277

# %%
# 질적 변수
qual_df = train[['snowing']]

# 양적 변수
quan_df = train.drop(columns = ['id', 'snowing'])

# %%
quan_df.hist(bins=100, figsize=(18, 18
                               ))
# Out:
# array([[<AxesSubplot: title={'center': 'temperature'}>,
#         <AxesSubplot: title={'center': 'pressure'}>,
#         <AxesSubplot: title={'center': 'humidity'}>],
#        [<AxesSubplot: title={'center': 'wind_speed'}>,
#         <AxesSubplot: title={'center': 'wind_direction'}>,
#         <AxesSubplot: title={'center': 'precipitation'}>],
#        [<AxesSubplot: title={'center': 'cloudiness'}>,
#         <AxesSubplot: title={'center': 'target'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
sns.countplot(x = qual_df['snowing'])
# Out:
# <AxesSubplot: xlabel='snowing', ylabel='count'>

# %%
#이상치 확인
fig, axes = plt.subplots(4,2, figsize=(10,18))

sns.boxplot(y = quan_df['temperature'], ax=axes[0][0])
sns.boxplot(y = quan_df['pressure'], ax=axes[0][1])

sns.boxplot(y = quan_df['humidity'], ax=axes[1][0])
sns.boxplot(y = quan_df['wind_speed'], ax=axes[1][1])

sns.boxplot(y = quan_df['wind_direction'], ax=axes[2][0])
sns.boxplot(y = quan_df['precipitation'], ax=axes[2][1])

sns.boxplot(y = quan_df['cloudiness'], ax=axes[3][0])
sns.boxplot(y = quan_df['target'], ax=axes[3][1])

sns.boxplot
# Out:
# <function seaborn.categorical.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)>

# %% [markdown]
# ### 이상치 확인 및 처리
# - 다른 컬럼들에 비해 train, test의 pressure, wind_speed, precipitation 가 이상치가 많이 확인 되었음

# %%
p_q1 = train['pressure'].quantile(0.25)
p_q3 = train['pressure'].quantile(0.75)
print(p_q1, p_q3)
# Out:
# 1012.6 1021.0

# %%
w_q1 = train['wind_speed'].quantile(0.25)
w_q3 = train['wind_speed'].quantile(0.75)
print(w_q1, w_q3)
# Out:
# 1.4 3.2

# %%
pre_q1 = train['precipitation'].quantile(0.25)
pre_q3 = train['precipitation'].quantile(0.75)
print(pre_q1, pre_q3)
# Out:
# 0.0 0.06

# %%
train2 = train.copy()
train2.drop(a, inplace=True)
train2
# Out:
#                 id  temperature  pressure  humidity  wind_speed  \
# 5      TRAIN_00005    24.850000    1011.2      64.6         2.2
# 7      TRAIN_00007    14.812000    1006.8      73.0         4.0
# 9      TRAIN_00009    20.770600    1004.4      67.0         1.4
# 14     TRAIN_00014    24.050000    1012.6      51.4         3.4
# 16     TRAIN_00016    12.494000    1008.6      85.0         2.2
# ...            ...          ...       ...       ...         ...
# 19253  TRAIN_19253    10.115006    1012.6      86.2         4.8
# 19257  TRAIN_19257    32.506000    1011.8      51.2         4.8
# 19271  TRAIN_19271    17.232000     993.2      78.2         2.0
# 19272  TRAIN_19272    13.748000     999.8      65.0         6.4
# 19274  TRAIN_19274    13.731863    1004.2      81.6         2.0
#
#        wind_direction  precipitation  snowing  cloudiness  target
# 5               126.0           0.00    False         0.0   1.971
# 7               172.0           0.12    False        60.0   9.110
# 9               215.2           0.00    False        11.2   7.333
# 14              156.0           0.00    False        23.0   4.899
# 16              118.0           0.06    False        56.0   7.419
# ...               ...            ...      ...         ...     ...
# 19253           140.6           0.24    False        46.2  12.376
# 19257           168.0           0.06    False        27.0   4.986
# 19271           198.0           0.06    False        26.4   3.670
# 19272           260.0           0.36    False        53.0   3.328
# 19274           222.2           0.06    False        44.2   6.374
#
# [4854 rows x 10 columns]

# %%
train2.describe()
# Out:
#        temperature     pressure     humidity   wind_speed  wind_direction  \
# count  4854.000000  4854.000000  4854.000000  4854.000000     4854.000000
# mean     15.519890  1005.384013    72.670911     3.113185      185.478492
# std       6.229878     6.748522    13.740638     1.678308       56.156281
# min      -0.208137   812.600000    26.800000     0.400000        6.000000
# 25%      11.154397  1001.800000    63.800000     1.800000      143.200000
# 50%      14.906000  1007.000000    75.000000     2.800000      187.000000
# 75%      19.383500  1010.400000    83.200000     4.000000      227.400000
# max      35.035800  1012.600000    98.400000    29.800000      338.000000
#
#        precipitation   cloudiness       target
# count    4854.000000  4854.000000  4854.000000
# mean        0.144771    36.506386     6.365811
# std         0.239326    20.004091     3.604778
# min         0.000000     0.000000     0.260000
# 25%         0.000000    20.000000     3.360250
# 50%         0.060000    36.600000     5.845000
# 75%         0.180000    51.950000     9.081750
# max         2.580000    93.600000    17.344000
